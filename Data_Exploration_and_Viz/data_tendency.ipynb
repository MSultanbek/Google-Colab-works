# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# importing required libraries

# %%
iq = pd.read_csv("/content/gpa_iq.csv")
iq.drop(["obs"], axis=1, inplace=True)
iq
# Out:
#       gpa   iq  gender  concept
# 0   7.940  111       2       67
# 1   8.292  107       2       43
# 2   4.643  100       2       52
# 3   7.470  107       2       66
# 4   8.882  114       1       58
# ..    ...  ...     ...      ...
# 73  9.000  112       1       60
# 74  9.500  112       1       70
# 75  6.057  114       2       51
# 76  6.057   93       1       21
# 77  6.938  106       2       56
#
# [78 rows x 4 columns]

# %% [markdown]
# describing

# %%
iq.describe()
# Out:
#              gpa          iq     gender    concept
# count  78.000000   78.000000  78.000000  78.000000
# mean    7.446538  108.923077   1.602564  56.961538
# std     2.099557   13.170973   0.492535  12.412229
# min     0.530000   72.000000   1.000000  20.000000
# 25%     6.278000  103.000000   1.000000  51.000000
# 50%     7.829000  110.000000   2.000000  59.500000
# 75%     8.983000  117.500000   2.000000  66.000000
# max    10.760000  136.000000   2.000000  80.000000

# %% [markdown]
# **percentile is part of data that is or below some point**

# %% [markdown]
# let's find 10-th percentile of gpa of students

# %%
gpa = iq["gpa"]
percentile10 = np.percentile(gpa, 10)
percentile10
# Out:
# 4.4501

# %% [markdown]
# in this example value 4.4501 shows us that 10% of data is or below point 4.4501

# %%
gpa = iq["gpa"]
plt.hist(gpa)
plt.show()

# %% [markdown]
# and really, if we take a look into graph, we can see that about 10% of values of gpa are less than or equal to![1-s2.0-S2214629616302985-gr1.jpg](data:image/jpeg;base64,...) 5

# %% [markdown]
# **Mean is average of data. for example if we take all the means of iq data set**

# %% [markdown]
# finding mean

# %%
mean = np.mean(iq)
mean
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# gpa          7.446538
# iq         108.923077
# gender       1.602564
# concept     56.961538
# dtype: float64

# %% [markdown]
# we can see here, that, for example, mean value of iq of students is 108.92 (which is pretty high, by the way)

# %%
#IF YOU WANT TO CALCULATE MEAN BY YOUR HAND HERE IS THE WAY

#FIRST WE NEED TO FIND SUM OF VALUES
sumiq = iq['iq'].sum()
print("Sum of all iq values is = ", sumiq)
# Out:
# Sum of all iq values is =  8496

# %%
#THEN WE NEED TO DIVIDE IT TO THE NUMBER OF VALUES (WHICH IS, IN OUR EXAMPLE, 78)
meaniq = sumiq/78
meaniq
# Out:
# 108.92307692307692

# %% [markdown]
# we get the correct value, mean of the iq. But finding mean dont give us full understanding of the data.

# %% [markdown]
# let me show an example:

# %%
list1 = [-10, 0, 10, 20, 30]
list2 = [8, 9, 10, 11, 12]
print(np.mean(list1))
np.mean(list2)
# Out:
# 10.0
# 10.0

# %% [markdown]
# if we take this two lists, we can see that their means are exual, however, this lists are very not alike, to see it mathematically we use the idea of standart deviation

# %% [markdown]
# **standard deviation is dividing data into parts by variance of data**

# %% [markdown]
# variance of data, is how far values in data differentiate, it means the greater the variance value, the more the values differ in data

# %%
variance = np.var(iqval)
variance
# Out:
# 171.25049309664695

# %% [markdown]
# variance is defined by σ^2

# %% [markdown]
# **standard deviation is just square-root of variance, and defined by σ**

# %% [markdown]
# finding standard deviation

# %%
std = np.std(iq)
std
# Out:
# gpa         2.086055
# iq         13.086271
# gender      0.489368
# concept    12.332407
# dtype: float64

# %%
#IF YOU WANT TO FIND VARIANCE BY HANDS, THERE IS SOME CODE
v78 = 0
m = iq["iq"].sum()/78
for i in range(78):
  single = (m - iq.at[i, "iq"])
  v78 += single**2

v = v78/78
print("Variance is = ", v)
# Out:
# 171.25049309664695

# %%
#AND IF YOU WANT TO FIND STANDARD DEVIATION
stan = v**(1/2)
stan
# Out:
# 13.086271168543274

# %% [markdown]
# **CORRELATION IS RELATION BETWEEN TWO SET OF VALUES**

# %%
#LETS SEE ON EXAMPLE
plt.scatter(iq["gpa"],iq["iq"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# if we take a look on a graph, where gpa is x-axis and iq is y-axis, we can clearly see that the greater iq, the greater gpa

# %% [markdown]
# it means gpa and iq are positively correlated

# %% [markdown]
# **CASUALITY SHOWS HOW ONE THING CAN BE CAUSE OF SOME OTHER**

# %% [markdown]
# for example if we take data of the usage electricity during day, we know that at the evening usage of electricity is high, but it doesn't mean that usage of electricity brings us evening, actually it's opposite, evening (and end of job, coming home) causes more usage of electricity

# %% [markdown]
# It means correlation not equals casuality

# %% [markdown]
# **CORRELATION MATRIX IS MATRIX THAT SHOWS HOW DIFFERENT COLUMNS ARE CORRELATED WITH EACH OTHER**

# %%
#IF YOU WANT TO SEE WITH CORRELATION VALUES
iq.corr()
# Out:
#               gpa        iq    gender   concept
# gpa      1.000000  0.633731 -0.097334  0.541833
# iq       0.633731  1.000000  0.191418  0.493148
# gender  -0.097334  0.191418  1.000000  0.095186
# concept  0.541833  0.493148  0.095186  1.000000

# %%
#MORE VISUAL METHOD IS
plt.matshow(iq.corr())
plt.show()
